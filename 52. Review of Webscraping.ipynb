# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Web Scraping Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab you will be able to:

# %% [markdown]
# *   Download a webpage using requests module
# *   Scrape all links from a web page
# *   Scrape all image urls from a web page
# *   Scrape data from html tables

# %% [markdown]
# ## Scrape [www.ibm.com](http://www.ibm.com/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01)

# %% [markdown]
# Import the required modules and functions

# %%
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a web page

# %% [markdown]
# Download the contents of the web page

# %%
url = "http://www.ibm.com"

# %%
# get the contents of the webpage in text format and store in a variable called data
data  = requests.get(url).text 
print(data)
# Out:
# <!DOCTYPE html>
# <html lang="de-de" dir="ltr">
#   <head>
#     <meta charset="utf-8" />
# <script>digitalData = {
#     "page": {
#         "category": [],
#         "pageInfo": {
#             "language": "de-DE",
#             "country": "DE",
#             "publisher": "IBM Corporation",
#             "version": "v19",
#             "ibm": {
#                 "contentDelivery": "Drupal 9",
#                 "contentProducer": "2598578 - Page Builder",
#                 "owner": "Peter Barros/White Plains/IBM",
#                 "siteID": "DRUPAL",
#                 "contactModuleConfiguration": {
#                     "contactInformationBundleKey": {
#                         "focusArea": "Cross IBM - About IBM",
#                         "languageCode": "de",
#                         "regionCode": "DE"
#                     },
#                     "contactModuleTranslationKey": {
#                         "languageCode": "de",
#                         "regionCode": "DE"
#                     }
#                 },
#                 "config": {
#                     "masthead": {
#                         "type": "default"
#                     },
#                     "footer": {
#                         "type": "default"
#                     }
#                 }
#             },
#             "publishDate": "2022-08-26",
#             "effectiveDate": "2021-03-08",
#             "expiryDate": "2026-08-26"
#         }
#     }
# }</script>
# <meta name="geo.country" content="DE" />
# <link rel="canonical" href="https://www.ibm.com/de-de" />
# <meta name="robots" content="index, follow" />
# <meta name="referrer" content="no-referrer-when-downgrade" />
# <meta name="rights" content="© Copyright IBM Corporation 2022" />
# <meta name="description" content="Seit mehr als einem Jahrhundert widmet sich IBM dem Erfolg jedes Kunden und der Schaffung von Innovationen, die für die Welt wichtig sind" />
# <meta property="og:type" content="website" />
# <meta property="og:url" content="https://www.ibm.com/de-de" />
# <meta property="og:title" content="IBM" />
# <meta property="og:description" content="Seit mehr als einem Jahrhundert widmet sich IBM dem Erfolg jedes Kunden und der Schaffung von Innovationen, die für die Welt wichtig sind" />
# <meta property="og:image" content="https://1.cms.s81c.com/sites/default/files/2021-02-17/20210215-ls-red-hat-cloud-2304x983.jpg" />
# <meta property="og:locale" content="de-de" />
# <meta name="twitter:card" content="summary" />
# <script>cpp = {"path":"\/cloud\/ajax\/product\/{product}"}</script>
# <meta name="viewport" content="width=device-width, initial-scale=1.0" />
# <script data-title="Components design metadata">/*
# Leadspace: v19 - Module 5E - Leadspace (5E) IBM Pop-up Wien
#
# Bands/Sections:
# 1. v19 - Module 12A - Newsflash (12A)
# 2. v19 - Carousel Module 1B - Features (1B)
# 3. v19 - Carousel Module 1B - Trials (1B)
# 4. v19 - Carousel Module 2B - Products (2B)
# 5. v19 - Module 11A (Double) - Content Spotlight (11A)
#
# */</script>
# <link rel="alternate" hreflang="en-af" href="https://www.ibm.com/af-en" />
# <link rel="alternate" hreflang="fr-dz" href="https://www.ibm.com/dz-fr" />
# <link rel="alternate" hreflang="pt-ao" href="https://www.ibm.com/ao-pt" />
# <link rel="alternate" hreflang="en-ai" href="https://www.ibm.com/ai-en" />
# <link rel="alternate" hreflang="en-ag" href="https://www.ibm.com/ag-en" />
# <link rel="alternate" hreflang="es-ar" href="https://www.ibm.com/ar-es" />
# <link rel="alternate" hreflang="en-aw" href="https://www.ibm.com/aw-en" />
# <link rel="alternate" hreflang="en-au" href="https://www.ibm.com/au-en" />
# <link rel="alternate" hreflang="de-at" href="https://www.ibm.com/at-de" />
# <link rel="alternate" hreflang="en-bs" href="https://www.ibm.com/bs-en" />
# <link rel="alternate" hreflang="en-bh" href="https://www.ibm.com/bh-en" />
# <link rel="alternate" hreflang="en-bd" href="https://www.ibm.com/bd-en" />
# <link rel="alternate" hreflang="en-bb" href="https://www.ibm.com/bb-en" />
# <link rel="alternate" hreflang="en-be" href="https://www.ibm.com/be-en" />
# <link rel="alternate" hreflang="en-bm" href="https://www.ibm.com/bm-en" />
# <link rel="alternate" hreflang="es-bo" href="https://www.ibm.com/bo-es" />
# <link rel="alternate" hreflang="en-bw" href="https://www.ibm.com/bw-en" />
# <link rel="alternate" hreflang="pt-br" href="https://www.ibm.com/br-pt" />
# <link rel="alternate" hreflang="en-vg" href="https://www.ibm.com/vg-en" />
# <link rel="alternate" hreflang="en-bn" href="https://www.ibm.com/bn-en" />
# <link rel="alternate" hreflang="en-bg" href="https://www.ibm.com/bg-en" />
# <link rel="alternate" hreflang="fr-bf" href="https://www.ibm.com/bf-fr" />
# <link rel="alternate" hreflang="en-kh" href="https://www.ibm.com/kh-en" />
# <link rel="alternate" hreflang="fr-cm" href="https://www.ibm.com/cm-fr" />
# <link rel="alternate" hreflang="en-ca" href="https://www.ibm.com/ca-en" />
# <link rel="alternate" hreflang="fr-ca" href="https://www.ibm.com/ca-fr" />
# <link rel="alternate" hreflang="en-ky" href="https://www.ibm.com/ky-en" />
# <link rel="alternate" hreflang="fr-td" href="https://www.ibm.com/td-fr" />
# <link rel="alternate" hreflang="es-cl" href="https://www.ibm.com/cl-es" />
# <link rel="alternate" hreflang="zh-cn" href="https://www.ibm.com/cn-zh" />
# <link rel="alternate" hreflang="es-co" href="https://www.ibm.com/co-es" />
# <link rel="alternate" hreflang="fr-cd" href="https://www.ibm.com/cd-fr" />
# <link rel="alternate" hreflang="fr-cg" href="https://www.ibm.com/cg-fr" />
# <link rel="alternate" hreflang="es-cr" href="https://www.ibm.com/cr-es" />
# <link rel="alternate" hreflang="en-hr" href="https://www.ibm.com/hr-en" />
# <link rel="alternate" hreflang="en-cw" href="https://www.ibm.com/cw-en" />
# <link rel="alternate" hreflang="en-cy" href="https://www.ibm.com/cy-en" />
# <link rel="alternate" hreflang="en-cz" href="https://www.ibm.com/cz-en" />
# <link rel="alternate" hreflang="en-dm" href="https://www.ibm.com/dm-en" />
# <link rel="alternate" hreflang="en-dk" href="https://www.ibm.com/dk-en" />
# <link rel="alternate" hreflang="es-ec" href="https://www.ibm.com/ec-es" />
# <link rel="alternate" hreflang="en-eg" href="https://www.ibm.com/eg-en" />
# <link rel="alternate" hreflang="en-ee" href="https://www.ibm.com/ee-en" />
# <link rel="alternate" hreflang="en-et" href="https://www.ibm.com/et-en" />
# <link rel="alternate" hreflang="en-fi" href="https://www.ibm.com/fi-en" />
# <link rel="alternate" hreflang="fr-fr" href="https://www.ibm.com/fr-fr" />
# <link rel="alternate" hreflang="fr-ga" href="https://www.ibm.com/ga-fr" />
# <link rel="alternate" hreflang="de-de" href="https://www.ibm.com/de-de" />
# <link rel="alternate" hreflang="en-gh" href="https://www.ibm.com/gh-en" />
# <link rel="alternate" hreflang="en-gr" href="https://www.ibm.com/gr-en" />
# <link rel="alternate" hreflang="en-gd" href="https://www.ibm.com/gd-en" />
# <link rel="alternate" hreflang="en-gy" href="https://www.ibm.com/gy-en" />
# <link rel="alternate" hreflang="en-hk" href="https://www.ibm.com/hk-en" />
# <link rel="alternate" hreflang="en-hu" href="https://www.ibm.com/hu-en" />
# <link rel="alternate" hreflang="en-in" href="https://www.ibm.com/in-en" />
# <link rel="alternate" hreflang="en-id" href="https://www.ibm.com/id-en" />
# <link rel="alternate" hreflang="en-iq" href="https://www.ibm.com/iq-en" />
# <link rel="alternate" hreflang="en-ie" href="https://www.ibm.com/ie-en" />
# <link rel="alternate" hreflang="en-il" href="https://www.ibm.com/il-en" />
# <link rel="alternate" hreflang="it-it" href="https://www.ibm.com/it-it" />
# <link rel="alternate" hreflang="fr-ci" href="https://www.ibm.com/ci-fr" />
# <link rel="alternate" hreflang="en-jm" href="https://www.ibm.com/jm-en" />
# <link rel="alternate" hreflang="ja-jp" href="https://www.ibm.com/jp-ja" />
# <link rel="alternate" hreflang="en-jo" href="https://www.ibm.com/jo-en" />
# <link rel="alternate" hreflang="en-kz" href="https://www.ibm.com/kz-en" />
# <link rel="alternate" hreflang="en-ke" href="https://www.ibm.com/ke-en" />
# <link rel="alternate" hreflang="ko-kr" href="https://www.ibm.com/kr-ko" />
# <link rel="alternate" hreflang="en-kw" href="https://www.ibm.com/kw-en" />
# <link rel="alternate" hreflang="en-lv" href="https://www.ibm.com/lv-en" />
# <link rel="alternate" hreflang="en-lb" href="https://www.ibm.com/lb-en" />
# <link rel="alternate" hreflang="en-ly" href="https://www.ibm.com/ly-en" />
# <link rel="alternate" hreflang="en-lt" href="https://www.ibm.com/lt-en" />
# <link rel="alternate" hreflang="fr-mg" href="https://www.ibm.com/mg-fr" />
# <link rel="alternate" hreflang="en-mw" href="https://www.ibm.com/mw-en" />
# <link rel="alternate" hreflang="en-my" href="https://www.ibm.com/my-en" />
# <link rel="alternate" hreflang="fr-mu" href="https://www.ibm.com/mu-fr" />
# <link rel="alternate" hreflang="es-mx" href="https://www.ibm.com/mx-es" />
# <link rel="alternate" hreflang="en-ms" href="https://www.ibm.com/ms-en" />
# <link rel="alternate" hreflang="fr-ma" href="https://www.ibm.com/ma-fr" />
# <link rel="alternate" hreflang="pt-mz" href="https://www.ibm.com/mz-pt" />
# <link rel="alternate" hreflang="en-na" href="https://www.ibm.com/na-en" />
# <link rel="alternate" hreflang="en-np" href="https://www.ibm.com/np-en" />
# <link rel="alternate" hreflang="en-nl" href="https://www.ibm.com/nl-en" />
# <link rel="alternate" hreflang="en-nz" href="https://www.ibm.com/nz-en" />
# <link rel="alternate" hreflang="fr-ne" href="https://www.ibm.com/ne-fr" />
# <link rel="alternate" hreflang="en-ng" href="https://www.ibm.com/ng-en" />
# <link rel="alternate" hreflang="en-no" href="https://www.ibm.com/no-en" />
# <link rel="alternate" hreflang="en-om" href="https://www.ibm.com/om-en" />
# <link rel="alternate" hreflang="en-pk" href="https://www.ibm.com/pk-en" />
# <link rel="alternate" hreflang="es-py" href="https://www.ibm.com/py-es" />
# <link rel="alternate" hreflang="es-pe" href="https://www.ibm.com/pe-es" />
# <link rel="alternate" hreflang="en-ph" href="https://www.ibm.com/ph-en" />
# <link rel="alternate" hreflang="pl-pl" href="https://www.ibm.com/pl-pl" />
# <link rel="alternate" hreflang="en-pt" href="https://www.ibm.com/pt-en" />
# <link rel="alternate" hreflang="en-qa" href="https://www.ibm.com/qa-en" />
# <link rel="alternate" hreflang="en-ro" href="https://www.ibm.com/ro-en" />
# <link rel="alternate" hreflang="ru-ru" href="https://www.ibm.com/ru-ru" />
# <link rel="alternate" hreflang="en-kn" href="https://www.ibm.com/kn-en" />
# <link rel="alternate" hreflang="en-lc" href="https://www.ibm.com/lc-en" />
# <link rel="alternate" hreflang="en-vc" href="https://www.ibm.com/vc-en" />
# <link rel="alternate" hreflang="en-sa" href="https://www.ibm.com/sa-en" />
# <link rel="alternate" hreflang="fr-sn" href="https://www.ibm.com/sn-fr" />
# <link rel="alternate" hreflang="en-rs" href="https://www.ibm.com/rs-en" />
# <link rel="alternate" hreflang="fr-sc" href="https://www.ibm.com/sc-fr" />
# <link rel="alternate" hreflang="en-sl" href="https://www.ibm.com/sl-en" />
# <link rel="alternate" hreflang="en-sg" href="https://www.ibm.com/sg-en" />
# <link rel="alternate" hreflang="en-sk" href="https://www.ibm.com/sk-en" />
# <link rel="alternate" hreflang="en-si" href="https://www.ibm.com/si-en" />
# <link rel="alternate" hreflang="en-za" href="https://www.ibm.com/za-en" />
# <link rel="alternate" hreflang="es-es" href="https://www.ibm.com/es-es" />
# <link rel="alternate" hreflang="en-lk" href="https://www.ibm.com/lk-en" />
# <link rel="alternate" hreflang="en-sr" href="https://www.ibm.com/sr-en" />
# <link rel="alternate" hreflang="en-se" href="https://www.ibm.com/se-en" />
# <link rel="alternate" hreflang="fr-ch" href="https://www.ibm.com/ch-fr" />
# <link rel="alternate" hreflang="de-ch" href="https://www.ibm.com/ch-de" />
# <link rel="alternate" hreflang="zh-tw" href="https://www.ibm.com/tw-zh" />
# <link rel="alternate" hreflang="en-tz" href="https://www.ibm.com/tz-en" />
# <link rel="alternate" hreflang="en-th" href="https://www.ibm.com/th-en" />
# <link rel="alternate" hreflang="en-tt" href="https://www.ibm.com/tt-en" />
# <link rel="alternate" hreflang="fr-tn" href="https://www.ibm.com/tn-fr" />
# <link rel="alternate" hreflang="tr-tr" href="https://www.ibm.com/tr-tr" />
# <link rel="alternate" hreflang="en-ye" href="https://www.ibm.com/ye-en" />
# <link rel="alternate" hreflang="en-tc" href="https://www.ibm.com/tc-en" />
# <link rel="alternate" hreflang="en-ua" href="https://www.ibm.com/ua-en" />
# <link rel="alternate" hreflang="en-ug" href="https://www.ibm.com/ug-en" />
# <link rel="alternate" hreflang="en-ae" href="https://www.ibm.com/ae-en" />
# <link rel="alternate" hreflang="en-gb" href="https://www.ibm.com/uk-en" />
# <link rel="alternate" hreflang="es-uy" href="https://www.ibm.com/uy-es" />
# <link rel="alternate" hreflang="en-uz" href="https://www.ibm.com/uz-en" />
# <link rel="alternate" hreflang="es-ve" href="https://www.ibm.com/ve-es" />
# <link rel="alternate" hreflang="en-vn" href="https://www.ibm.com/vn-en" />
# <link rel="alternate" hreflang="en-zm" href="https://www.ibm.com/zm-en" />
# <link rel="alternate" hreflang="en-zw" href="https://www.ibm.com/zw-en" />
#
#     <title>IBM  - Deutschland | IBM</title>
#     <link rel='dns-prefetch' href='//1.www.s81c.com' />
# <link rel='preconnect' href='//1.www.s81c.com' />
#     <link href="//1.www.s81c.com/common/v18/drupal/css/www.css" rel="preload" as="style"  />
#     <link rel="stylesheet" href="//1.www.s81c.com/common/v18/drupal/css/www.css" media="all" />
# <link href="//1.www.s81c.com/common/v18/drupal/css/grid-fluid.css" rel="preload" as="style"  />
# <link rel="stylesheet" href="//1.www.s81c.com/common/v18/drupal/css/grid-fluid.css" media="all" />
# <link href="//1.www.s81c.com/common/v18/drupal/css/tables.css" rel="preload" as="style"  />
# <link rel="stylesheet" href="//1.www.s81c.com/common/v18/drupal/css/tables.css" media="all" />
# <link rel="preload" href="//1.www.s81c.com/common/fonts/plex/v1/ibmplexsans-regular.woff2" as="font" type="font/woff2" crossorigin>
# <link rel="preload" href="//1.www.s81c.com/common/fonts/plex/v1/ibmplexsans-regularitalic.woff2" as="font" type="font/woff2" crossorigin>
# <link rel="preload" href="//1.www.s81c.com/common/fonts/plex/v1/ibmplexsans-semibold.woff2" as="font" type="font/woff2" crossorigin>
# <link rel="preload" href="//1.www.s81c.com/common/fonts/icons-ibm-v12.woff" as="font" type="font/woff" crossorigin>
# <link rel="preload" href="//1.www.s81c.com/common/fonts/plex/v1/ibmplexsans-light.woff2" as="font" type="font/woff2" crossorigin>
#     <link rel="stylesheet" media="all" href="//1.www.s81c.com/common/v19a/css/www.css" />
# <link rel="stylesheet" media="all" href="//1.cms.s81c.com/sites/default/files/css/css_lNFjH-TWqtkHIuTHLZCRDzuk10ObPn2eM1te0FSDGI0.css" />
# <link rel="stylesheet" media="all" href="//1.cms.s81c.com/sites/default/files/css/css_85KPJRKrhmnymPvMs-oSJCI72T4_MxK5_sB_aTl-i90.css" />
#
#     <script src="//1.www.s81c.com/common/stats/ibm-common.js"></script>
# <script src="//1.www.s81c.com/common/v18/drupal/js/www.js" defer></script>
# <script src="//1.www.s81c.com/common/carbon/plex/load-non-latin-plex.js" defer></script>
# <script src="//1.www.s81c.com/common/v19a/js/www.js" defer></script>
#
#     <noscript>
#       <link rel="stylesheet" type="text/css" href="//1.cms.s81c.com/modules/contrib/hc_fractal/dist/css/no-js.css" />
#     </noscript>
#   </head>
#   <body id="ibm-com"  uuid="13191044-6a14-4729-9e45-bd694fad7d27" class="path-node page-node-type-page-wrapper ibm-type">
#
#       <div class="dialog-off-canvas-main-canvas" data-off-canvas-main-canvas>
#     <div id="ibm-top" class="ibm-landing-page">
#     <div class="region region-masthead">
#
#
#
#
#
# <div id="ibm-masthead" role="banner" aria-label="IBM" data-mhtype="full" class="simple  ibm-mhtype-full">
#   <div id="ibm-universal-nav">
#     <nav role="navigation" aria-label="IBM">
#       <div id="ibm-home"><a href="https://www.ibm.com/de/de">IBM®</a></div>
#                     <!-- Menu -->
#
#               <ul aria-label="" role="toolbar" class="ibm-masthead-categories">
#
#                             <li role="presentation" class="ibm-mh-mainitem">
#               <a role="button" href="https://www.ibm.com/lets-create/de-de?lnk=hpmlc" class="" data-menutype="none" id="mhitem-mms0" data-linkid="mms0">Let’s Create</a>
#                         </li>
#                             <li role="presentation" class="ibm-mh-mainitem ibm-hasmenu">
#               <a role="button" href="" class="ibm-chevron-down-link ibm-icon-after" data-menutype="dropdown" id="mhitem-mms1" data-linkid="mms1">Produkte &amp; Lösungen</a>
#                               <ul class="ibm-dropdown-menu">
#                                                           <li>
#                       <a href="https://www.ibm.com/de-de/products?lnk=hpmps_bupr_dede&amp;lnk2=link">Top Produkte &amp; Plattformen</a>
#                     </li>
#                                         <li>
#                       <a href="https://www.ibm.com/de-de/industries?lnk=hpmps_buin_dede&amp;lnk2=link">Branchenlösungen</a>
#                     </li>
#                                         <li>
#                       <a href="https://www.ibm.com/de-de/watson?lnk=hpmps_buai_dede&amp;lnk2=link">Künstliche Intelligenz</a>
#                     </li>
#                                         <li>
#                       <a href="https://www.ibm.com/de-de/about/automation?lnk=hpmps_buau_dede&amp;lnk2=link">Automatisierung</a>
#                     </li>
#                                         <li>
#                       <a href="https://www.ibm.com/de-de/blockchain?lnk=hpmps_bubc_dede&amp;lnk2=link">Blockchain</a>
#                     </li>
#                                         <li>
#                       <a href="https://www.ibm.com/de-de/business-operations?lnk=hpmps_buop_dede&amp;lnk2=link">Business operations</a>
#                     </li>
#                                         <li>
#                       <a href="https://www.ibm.com/de-de/cloud?lnk=hpmps_bucl_dede&amp;lnk2=link">Cloud computing</a>
#                     </li>
#                                         <li>
#                       <a href="https://www.ibm.com/de-de/analytics?lnk=hpmps_buda_dede&amp;lnk2=link">Daten &amp; Analysen</a>
#                     </li>
#                                         <li>
#                       <a href="https://www.ibm.com/de-de/it-infrastructure?lnk=hpmps_buit_dede&amp;lnk2=link">IT-Infrastruktur</a>
#                     </li>
#                                         <li>
#                       <a href="https://www.ibm.com/de-de/security?lnk=hpmps_buse_dede&amp;lnk2=link">Security</a>
#                     </li>
#                                         <li>
#                       <a href="https://www.ibm.com/de-de/supply-chain?lnk=hpmps_busc_dede&amp;lnk2=link">Lieferketten</a>
#                     </li>
#                                         <li>
#                       <a href="https://www.ibm.com/de-de/financing?lnk=hpmps_bufi_dede&amp;lnk2=link">Flexible Zahlungspläne</a>
#                     </li>
#                                         <li>
#                       <a href="https://www.ibm.com/de-de/products?lnk=hpmps_buall_dede&amp;lnk2=link">Alle Produkte anzeigen</a>
#                     </li>
#                                                       </ul>
#                         </li>
#                             <li role="presentation" class="ibm-mh-mainitem ibm-hasmenu">
#               <a role="button" href="" class="ibm-chevron-down-link ibm-icon-after" data-menutype="dropdown" id="mhitem-mms2" data-linkid="mms2">Beratung und Dienstleistungen</a>
#                               <ul class="ibm-dropdown-menu">
#                                                           <li>
#                       <a href="https://www.ibm.com/consulting/de-de/?lnk=hpmsc_buco_dede&amp;lnk2=learn">IBM-Beratung</a>
#                     </li>
#                                         <li>
#                       <a href="https://www.ibm.com/de-de/services/business?lnk=hpmsc_bups_dede&amp;lnk2=link">Geschäftsprozesslösungen</a>
#                     </li>
#                                         <li>
#                       <a href="https://www.ibm.com/de-de/services?lnk=hpmsc_budbs_dede&amp;lnk2=link">Design und Unternehmensstrategie</a>
#                     </li>
#                                         <li>
#                       <a href="https://www.ibm.com/de-de/cloud/services?lnk=hpmsc_buhs_dede">Cloud Consulting Services</a>
#                     </li>
#                                         <li>
#                       <a href="https://www.ibm.com/de-de/services/talent-management?lnk=hpmsc_buta_dede&amp;lnk2=link">Talent und Transformation</a>
#                     </li>
#                                         <li>
#                       <a href="https://www.ibm.com/de-de/services/applications?lnk=hpmsc_buas_dede&amp;lnk2=link">Anwendungsdienstleistungen</a>
#                     </li>
#                                         <li>
#                       <a href="https://www.ibm.com/de-de/garage?lnk=hpmsc_buas_dede&amp;lnk2=link">IBM Garage</a>
#                     </li>
#                                         <li>
#                       <a href="https://www.ibm.com/de-de/security/services?lnk=hpmsc_buse_dede&amp;lnk2=link">Security Dienstleistungen</a>
#                     </li>
#                                         <li>
#                       <a href="https://www.ibm.com/de-de/services/technology-support?lnk=hpmsc_busv_dede&amp;lnk2=link">Technology Support Services</a>
#                     </li>
#                                         <li>
#                       <a href="https://www.ibm.com/de-de/financing?lnk=hpmsc_bufi_dede&amp;lnk2=link">Flexible Zahlungspläne</a>
#                     </li>
#                                         <li>
#                       <a href="https://www.ibm.com/de-de/services?lnk=hpmsc_buall_dede&amp;lnk2=link">Alle Services anzeigen</a>
#                     </li>
#                                                       </ul>
#                         </li>
#                             <li role="presentation" class="ibm-mh-mainitem ibm-hasmenu">
#               <a role="button" href="" class="ibm-chevron-down-link ibm-icon-after" data-menutype="dropdown" id="mhitem-mms3" data-linkid="mms3">Learn &amp; Support</a>
#                               <ul class="ibm-dropdown-menu">
#                                                           <li>
#                       <a href="https://www.ibm.com/support/de/de/?lnk=hpmls_busu_dede&amp;lnk2=link">Support</a>
#                     </li>
#                                         <li>
#                       <a href="https://www.ibm.com/support/knowledgecenter/?lnk=hpmls_budc_dede&amp;lnk2=link">Dokumentation</a>
#                     </li>
#                                         <li>
#                       <a href="https://developer.ibm.com/?lnk=hpmls_bude_dede&amp;lnk2=link">IBM Developer</a>
#                     </li>
#                                         <li>
#                       <a href="https://www.ibm.com/training/?lnk=hpmls_butr_dede&amp;lnk2=link">Schulungen</a>
#                     </li>
#                                         <li>
#                       <a href="https://www.ibm.com/blogs/?lnk=hpmls_bure_dede&amp;lnk2=link">Ressourcen</a>
#                     </li>
#                                         <li>
#                       <a href="https://www.ibm.com/de-de/cloud/learn?lnk=hpmls_buwi_dede&amp;lnk2=link">Was ist...</a>
#                     </li>
#                                                       </ul>
#                         </li>
#                             <li role="presentation" class="ibm-mh-mainitem ibm-hasmenu">
#               <a role="button" href="" class="ibm-chevron-down-link ibm-icon-after" data-menutype="dropdown" id="mhitem-mms4" data-linkid="mms4">Mehr erfahren</a>
#                               <ul class="ibm-dropdown-menu">
#                                                           <li>
#                       <a href="https://www.ibm.com/de-de/partnerworld/public?lnk=hpmex_bupa_dede&amp;lnk2=link">PartnerWorld</a>
#                     </li>
#                                         <li>
#                       <a href="https://www.research.ibm.com/?lnk=hpmex_bure_dede&amp;lnk2=link">IBM Forschung</a>
#                     </li>
#                                         <li>
#                       <a href="https://www.ibm.com/de-de/about?lnk=hpmex_buab_dede&amp;lnk2=link">Über IBM</a>
#                     </li>
#                                         <li>
#                       <a href="https://www.ibm.com/de-de/impact/covid-19?lnk=hpmex_buco_dede&amp;lnk2=link">COVID-19</a>
#                     </li>
#                                                       </ul>
#                         </li>
#               </ul>
#
#       <ul id="ibm-menu-links" role="toolbar" aria-label="Site map">
#         <li><a href="https://www.ibm.com/sitemap/de/de">Sitemap</a></li>
#       </ul>
#     </nav>
#
#           <div id="ibm-search-module" role="search" aria-labelledby="ibm-masthead">
#         <form id="ibm-search-form" action="https://www.ibm.com/Search/" method="get">
#           <p>
#             <label for="q">IBM</label>
#             <input type="text" maxlength="100" value="" placeholder=Suchen name="q" id="q" aria-label="Search"/>
#             <input type="hidden" value="18" name="v"/>
#             <input type="hidden" value="utf" name="en"/>
#             <input type="hidden" value="de" name="lang"/>
#             <input type="hidden" value="de" name="cc"/>
#             <input type="submit" id="ibm-search" class="ibm-btn-search" value="Submit"/>
#           </p>
#         </form>
#       </div>
#
#
#   </div>
#   </div>
#
#   </div>
#
#   <div id="ibm-content-wrapper">
#       <header  aria-label="Navigation Header">
#
#
#   </header>
#
#
#
#       <div class="region region-help">
#     <div data-drupal-messages-fallback class="hidden"></div>
#
#   </div>
#
#       <div class="region region-content">
#     <div id="block-ibm-duo-content">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   <section  role="article" about="/de-de/node/2598576" class="ibm-duo-leadspace ibm-duo-leadspace-large ibm-background-gray-10" data-bg-lazy-load>
#     <div class="ibm-grid-container ibm-duo-leadspace-large__container">
#       <div class="ibm-grid-col-sm-4-4 ibm-grid-col-md-8-8 ibm-grid-col-lg-16-16 ibm-grid-col-seamless ibm-duo-leadspace-large__bg">
#
#                   <div class="picturefill-background ibm-duo-leadspace-large__image ani-reveal ani-fadeIn">
#             <span data-src="//1.cms.s81c.com/sites/default/files/2022-08-25/IBM_PopUp_Banner_Rendering_2304x983_Overlay_1.jpg"></span>
#             <span data-src="//1.cms.s81c.com/sites/default/files/2022-08-25/IBM_PopUp_Banner_Rendering_720x360_0.png" data-media="(min-width: 320px)"></span>
#             <span data-src="//1.cms.s81c.com/sites/default/files/2022-08-25/IBM_PopUp_Banner_Rendering_2304x983_Overlay_1.jpg" data-media="(min-width: 672px)"></span>
#           </div>
#
#               </div>
#
#       <div class="ibm-grid-col-sm-4-4 ibm-grid-col-md-8-4 ibm-grid-col-lg-16-7 ibm-duo-leadspace-large__content">
#                   <div class="ibm-grid-col-sm-4-3 ibm-grid-col-lg-16-12 ibm-grid-col-xlg-16-16 ibm-grid-col-seamless ibm-mb-4 ibm-duo-leadspace-large__headline ani-reveal ani-fadeInUp" data-wow-delay=".2s">
#             <h1 class="bx--type-expressive-heading-05 bx--type-light ibm-textcolor-gray-90 ibm-pb-0 ibm-mb-0">
#                   <span>IBM Pop-up<br />
# Roadshow 2022</span>
#
#             </h1>
#           </div>
#
#         <div class="ibm-duo-leadspace-large__subhead">
#                       <div class="ibm-grid-col-sm-4-3 ibm-grid-col-lg-16-10 ibm-grid-col-xlg-16-12 ibm-grid-col-seamless ani-reveal ani-fadeInUp" data-wow-delay=".4s">
#               <p class="bx--type-expressive-heading-03 ibm-textcolor-gray-70 ibm-mb-0">
#                     <span>Zahlreiche Events, Workshops und eine interaktive Ausstellung rund um die Zukunft der Technologie</span>
#
#               </p>
#             </div>
#
#
#             <div class="ibm-btn-row ibm-button-link ibm-mt-4 ani-reveal ani-fadeInUp" data-wow-delay=".6s">
#
#
#
#
#
#
#
#
#
#
#
#   <div class='ibm-duo-button-item'>
#     <a  target="_self" href="https://www.ibm.com/de-de/events/think/pop-up-wien?lnk=dehpv18l1" class="ibm-btn-pri ibm-duo-btn-cta ibm-duo-u--link-icon">
#       IBM Pop-up Wien: 18.-23. September
#
#
#
#
#                       <svg focusable="false" class="ibm-duo-u--link-icon--arrow-right" preserveAspectRatio="xMidYMid meet" xmlns="http://www.w3.org/2000/svg" fill="currentColor" aria-hidden="true" aria-label="View this link" width="20" height="20" viewBox="0 0 20 20" slot="icon"><path d="M11.8 2.8L10.8 3.8 16.2 9.3 1 9.3 1 10.7 16.2 10.7 10.8 16.2 11.8 17.2 19 10z"></path></svg>
#
#
#     </a>
#   </div>
#
#
#
#
#
#
#
#
#
#
#
#
#   <div class='ibm-duo-button-item'>
#     <a  target="_self" href="https://www.ibm.com/de-de/events/think/pop-up-koeln?lnk=dehpv18l2" class="ibm-btn-sec ibm-duo-btn-cta ibm-duo-u--link-icon ibm-btn-sec--blue">
#       IBM Pop-up Köln: 17.-27. Oktober
#
#
#
#
#                       <svg focusable="false" class="ibm-duo-u--link-icon--arrow-right" preserveAspectRatio="xMidYMid meet" xmlns="http://www.w3.org/2000/svg" fill="currentColor" aria-hidden="true" aria-label="View this link" width="20" height="20" viewBox="0 0 20 20" slot="icon"><path d="M11.8 2.8L10.8 3.8 16.2 9.3 1 9.3 1 10.7 16.2 10.7 10.8 16.2 11.8 17.2 19 10z"></path></svg>
#
#
#     </a>
#   </div>
#
#       </div>
#   <div class="ibm-grid-col-sm-4-4 ani-reveal ani-fadeInUp" data-wow-delay=".7s">
#       </div>
#
#
#         </div>
#       </div>
#
#       <div class="ibm-grid-col-sm-4-1 ibm-grid-col-md-8-0 ibm-grid-col-lg-16-1"></div>
#
#       <div class="ibm-grid-col-sm-4-4 ibm-grid-col-md-8-4 ibm-grid-col-lg-16-8 ibm-grid-col-xlg-16-8 ibm-grid-col-seamless ibm-duo-leadspace-large__media-full">
#               </div>
#     </div>
#   </section>
#
#
#
#
#
#
#
#
# <main role="main" aria-labelledby="ibm-pagetitle-h1">
#   <div id="ibm-pcon">
#     <div id="ibm-content">
#       <div id="ibm-content-body" class="ibm-padding-top-0">
#         <div id="ibm-content-main">
#
#
#           <div class="node__content">
#
#
#
#
#
#
#
#
#   <section  role="article" about="/de-de/node/3108334" id="3108334" class="ibm-duo-band ibm-duo-module-12a ibm-background-gray-100 ibm-duo-u--gradient ibm-duo-u--gradient--cloud" data-bg-lazy-load>
#
#
#
#
#
#
#
#
#
# <div class="ibm-grid-container ibm-duo-u--pt-4 ibm-duo-u--pb-4 ">
#   <div class="ibm-grid-col-sm-4-4 ibm-grid-col-md-8-6 ibm-grid-col-lg-16-8 ibm-duo-module-12a__content">
#
#           <div class="ibm-duo-module-12a__subhead ibm-textcolor-gray-10">
#                     <p><em>IBM Security veröffentlicht die alljährliche "Cost of a Data Breach"-Studie 2022</em></p>
#
#       </div>
#
#       </div>
#
#
#     <div class="ibm-grid-col-sm-4-0 ibm-grid-col-md-8-2 ibm-grid-col-lg-16-4"></div>
#           <div class="ibm-grid-col-sm-4-4 ibm-grid-col-md-8-4 ibm-grid-col-lg-16-4 ibm-duo-module-12a__cta ani-reveal ani-fadeInUp">
#
#
#
#
#
#
#
#
#
#
#
#   <div class='ibm-duo-button-item'>
#     <a  target="_blank" href="https://de.newsroom.ibm.com/2022-07-27-Cost-of-a-Data-Breach-Studie-2022?lnk=dehpv18nf1" class="ibm-btn-pri ibm-duo-btn-cta ibm-duo-u--link-icon">
#       Mehr erfahren
#
#
#
#
#                       <svg focusable="false" class="ibm-duo-u--link-icon--arrow-right" preserveAspectRatio="xMidYMid meet" xmlns="http://www.w3.org/2000/svg" fill="currentColor" aria-hidden="true" aria-label="View this link" width="20" height="20" viewBox="0 0 20 20" slot="icon"><path d="M11.8 2.8L10.8 3.8 16.2 9.3 1 9.3 1 10.7 16.2 10.7 10.8 16.2 11.8 17.2 19 10z"></path></svg>
#
#
#     </a>
#   </div>
#
#               </div>
#       </div>
#
#
#               </section>
#
#
#
#
#
#
#
#
#   <section  role="article" about="/de-de/node/2598600" id="2598600" class="ibm-duo-band ibm-duo-module-1b ibm-duo-u--pt-4 ibm-duo-u--pb-4 ibm-background-white-core" data-bg-lazy-load>
#     <div class="ibm-grid-container ibm-duo-module-1b__container">
#       <div class="ibm-grid-col-sm-4-4 ibm-grid-col-md-8-4 ibm-grid-col-lg-16-4">
#
#
#   <div class="ibm-duo-heading__headline ibm-grid-col-sm-4-4 ibm-grid-col-md-8-6 ibm-grid-col-lg-16-8 ibm-grid-col-seamless ibm-mb-3 ani-reveal ani-fadeInUp">
#     <h2 class="bx--type-productive-heading-02 ibm-textcolor-gray-90 ibm-pb-0 ibm-mb-0">
#           <span > Im Unternehmen IBM  </span>
#
#     </h2>
#   </div>
#
#
#       </div>
#
#
#
#
#         <div class="ibm-grid-col-sm-4-4 ibm-grid-col-md-8-8 ibm-grid-col-lg-16-12 ibm-grid-col-seamless">
#           <div class="ibm-duo-carousel ibm-duo-carousel__1b ani-reveal ani-fadeInUp" data-widget="setsameheight" data-always="true" data-items=".ibm-duo-card__heading">
#
#           <button type="button" class="slick-arrow slick-prev" data-ibm-cm-avoid="true">
#       <svg focusable="false" preserveAspectRatio="xMidYMid meet" xmlns="http://www.w3.org/2000/svg" width="32" height="32" viewBox="0 0 32 32" aria-hidden="true" aria-label="Show previous content"><path d="m10 16l10-10l1.4 1.4l-8.6 8.6l8.6 8.6l-1.4 1.4l-10-10z" /></svg>
# </button>
#
#
#                       <div class="ibm-duo-carousel__item ibm-duo-carousel-1b__item">
#
#
#
#
#
#
#
#
#
#
# <div class="ibm-card ibm-duo-card ibm-duo-card--auto-height ibm-card--noborder ibm-mb-0">
#
#
#
#
#
#
#
#
#
#
#
#     <a  target="_self" href="https://www.ibm.com/de-de/events/turn-vision-into-action?lnk=dehpv18f1" class="ibm-blocklink ibm-duo-card__link ibm-duo-u--link-icon--rtl ibm-background-cool-gray-10 ibm-duo-card--hover-light">
#
#           <div class="ibm-card__image ibm-duo-card__image ibm-duo-u--ratio--sixteen-nine">
#
#
# <img loading="lazy" src="//1.cms.s81c.com/sites/default/files/2022-08-10/IBM_Turn_Vision_into_Action_2022-Webpage-444x254px.jpeg" alt="Sechs Pictogramme"
#         class=""
#   />
#
#                                                       </div>
#
#     <div class="ibm-card__content ibm-duo-card__content">
#       <div class="ibm-grid-container ibm-pb-3">
#                   <div class="ibm-grid-col-sm-4-4 ibm-grid-col-md-8-6 ibm-grid-col-lg-16-12 ibm-duo-card__heading">
#             <h3 class="bx--type-productive-heading-02 ibm-type-semibold ibm-mb-1 ibm-textcolor-gray-90 ibm-pb-0">
#                   <span > Turn Vision into Action – Gemeinsam Zukunft gestalten</span>
#
#             </h3>
#           </div>
#
#                   <div class="ibm-grid-col-sm-4-4 ibm-grid-col-md-8-6 ibm-grid-col-lg-16-14 ibm-duo-card__desc">
#             <div class="ibm-card__subheading bx--type-body-short-02 ibm-mb-0 ibm-textcolor-gray-70 ibm-pb-0">
#                           <p>Am 22. September diskutieren wir im IBM Pop-up direkt im MuseumsQuartier in Wien die wichtigsten Technologietrends, zeigen neue Ansätze zur Entwicklung von Innovationen und teilen erfolgreiche Projekte.</p>
#
#             </div>
#           </div>
#               </div>
#     </div>
#
#           <div class="ibm-card__bottom ibm-duo-card__bottom">
#           <div class="ibm-grid-container">
#             <div class="ibm-grid-col-sm-4-4 ibm-grid-col-md-8-8 ibm-grid-col-lg-16-16">
#
#
#
#
#
#
#
#
#
#     <p class="ibm-duo-u--link-icon ibm-textcolor-blue-60">
#     <span class="ibm-textcolor-blue-60">Jetzt anmelden und dabei sein</span>
#
#
#
#
#                       <svg focusable="false" class="ibm-duo-u--link-icon--arrow-right" preserveAspectRatio="xMidYMid meet" xmlns="http://www.w3.org/2000/svg" fill="currentColor" aria-hidden="true" aria-label="View this link" width="20" height="20" viewBox="0 0 20 20" slot="icon"><path d="M11.8 2.8L10.8 3.8 16.2 9.3 1 9.3 1 10.7 16.2 10.7 10.8 16.2 11.8 17.2 19 10z"></path></svg>
#
#
#   </p>
#
#             </div>
#           </div>
#       </div>
#
#
#   </a>
#
#     </div>
#
#
#               </div>
#                       <div class="ibm-duo-carousel__item ibm-duo-carousel-1b__item">
#
#
#
#
#
#
#
#
#
#
# <div class="ibm-card ibm-duo-card ibm-duo-card--auto-height ibm-card--noborder ibm-mb-0">
#
#
#
#
#
#
#
#
#
#
#
#     <a  target="_self" href="https://www.ibm.com/de-de/consulting/resources/design-data-led-experience-transformation?lnk=dehpv18f2" class="ibm-blocklink ibm-duo-card__link ibm-duo-u--link-icon--rtl ibm-background-cool-gray-10 ibm-duo-card--hover-light">
#
#           <div class="ibm-card__image ibm-duo-card__image ibm-duo-u--ratio--sixteen-nine">
#
#
# <img loading="lazy" src="//1.cms.s81c.com/sites/default/files/2022-08-16/20220815-consulting-design-data-led-experience-transformation-26852-444x33-444x254.jpg" alt="Hand zeigt auf ein Balkendiagramm"
#         class=""
#   />
#
#                                                       </div>
#
#     <div class="ibm-card__content ibm-duo-card__content">
#       <div class="ibm-grid-container ibm-pb-3">
#                   <div class="ibm-grid-col-sm-4-4 ibm-grid-col-md-8-6 ibm-grid-col-lg-16-12 ibm-duo-card__heading">
#             <h3 class="bx--type-productive-heading-02 ibm-type-semibold ibm-mb-1 ibm-textcolor-gray-90 ibm-pb-0">
#                   <span > Human-centered Transformation</span>
#
#             </h3>
#           </div>
#
#                   <div class="ibm-grid-col-sm-4-4 ibm-grid-col-md-8-6 ibm-grid-col-lg-16-14 ibm-duo-card__desc">
#             <div class="ibm-card__subheading bx--type-body-short-02 ibm-mb-0 ibm-textcolor-gray-70 ibm-pb-0">
#                           <p>Ein designorientierter, datengesteuerter Ansatz für das Kundenerlebnis bietet einen erheblichen Wettbewerbsvorteil.</p>
#
#             </div>
#           </div>
#               </div>
#     </div>
#
#           <div class="ibm-card__bottom ibm-duo-card__bottom">
#           <div class="ibm-grid-container">
#             <div class="ibm-grid-col-sm-4-4 ibm-grid-col-md-8-8 ibm-grid-col-lg-16-16">
#
#
#
#
#
#
#
#
#
#     <p class="ibm-duo-u--link-icon ibm-textcolor-blue-60">
#     <span class="ibm-textcolor-blue-60">Sehen Sie wie</span>
#
#
#
#
#                       <svg focusable="false" class="ibm-duo-u--link-icon--arrow-right" preserveAspectRatio="xMidYMid meet" xmlns="http://www.w3.org/2000/svg" fill="currentColor" aria-hidden="true" aria-label="View this link" width="20" height="20" viewBox="0 0 20 20" slot="icon"><path d="M11.8 2.8L10.8 3.8 16.2 9.3 1 9.3 1 10.7 16.2 10.7 10.8 16.2 11.8 17.2 19 10z"></path></svg>
#
#
#   </p>
#
#             </div>
#           </div>
#       </div>
#
#
#   </a>
#
#     </div>
#
#
#               </div>
#                       <div class="ibm-duo-carousel__item ibm-duo-carousel-1b__item">
#
#
#
#
#
#
#
#
#
#
# <div class="ibm-card ibm-duo-card ibm-duo-card--auto-height ibm-card--noborder ibm-mb-0">
#
#
#
#
#
#
#
#
#
#
#
#     <a  target="_self" href="https://www.ibm.com/de-de/it-infrastructure/power?lnk=dehpv18f3" class="ibm-blocklink ibm-duo-card__link ibm-duo-u--link-icon--rtl ibm-background-cool-gray-10 ibm-duo-card--hover-light">
#
#           <div class="ibm-card__image ibm-duo-card__image ibm-duo-u--ratio--sixteen-nine">
#
#
# <img loading="lazy" src="//1.cms.s81c.com/sites/default/files/2022-08-25/Power10-card-444x254.jpg" alt="Mann steht neben einem Power10 Server"
#         class=""
#   />
#
#                                                       </div>
#
#     <div class="ibm-card__content ibm-duo-card__content">
#       <div class="ibm-grid-container ibm-pb-3">
#                   <div class="ibm-grid-col-sm-4-4 ibm-grid-col-md-8-6 ibm-grid-col-lg-16-12 ibm-duo-card__heading">
#             <h3 class="bx--type-productive-heading-02 ibm-type-semibold ibm-mb-1 ibm-textcolor-gray-90 ibm-pb-0">
#                   <span > Entwickelt für Agilität</span>
#
#             </h3>
#           </div>
#
#                   <div class="ibm-grid-col-sm-4-4 ibm-grid-col-md-8-6 ibm-grid-col-lg-16-14 ibm-duo-card__desc">
#             <div class="ibm-card__subheading bx--type-body-short-02 ibm-mb-0 ibm-textcolor-gray-70 ibm-pb-0">
#                           <p>Die neuen Power10-Server — erstklassige Leistung für kritische Workloads in einer hybriden Umgebung.</p>
#
#             </div>
#           </div>
#               </div>
#     </div>
#
#           <div class="ibm-card__bottom ibm-duo-card__bottom">
#           <div class="ibm-grid-container">
#             <div class="ibm-grid-col-sm-4-4 ibm-grid-col-md-8-8 ibm-grid-col-lg-16-16">
#
#
#
#
#
#
#
#
#
#     <p class="ibm-duo-u--link-icon ibm-textcolor-blue-60">
#     <span class="ibm-textcolor-blue-60">Power10 entdecken</span>
#
#
#
#
#                       <svg focusable="false" class="ibm-duo-u--link-icon--arrow-right" preserveAspectRatio="xMidYMid meet" xmlns="http://www.w3.org/2000/svg" fill="currentColor" aria-hidden="true" aria-label="View this link" width="20" height="20" viewBox="0 0 20 20" slot="icon"><path d="M11.8 2.8L10.8 3.8 16.2 9.3 1 9.3 1 10.7 16.2 10.7 10.8 16.2 11.8 17.2 19 10z"></path></svg>
#
#
#   </p>
#
#             </div>
#           </div>
#       </div>
#
#
#   </a>
#
#     </div>
#
#
#               </div>
#                       <div class="ibm-duo-carousel__item ibm-duo-carousel-1b__item">
#
#
#
#
#
#
#
#
#
#
# <div class="ibm-card ibm-duo-card ibm-duo-card--auto-height ibm-card--noborder ibm-mb-0">
#
#
#
#
#
#
#
#
#
#
#
#     <a  target="_self" href="https://www.ibm.com/consulting/de-de?lnk=dehpv18f4" class="ibm-blocklink ibm-duo-card__link ibm-duo-u--link-icon--rtl ibm-background-cool-gray-10 ibm-duo-card--hover-light">
#
#           <div class="ibm-card__image ibm-duo-card__image ibm-duo-u--ratio--sixteen-nine">
#
#
# <img loading="lazy" src="//1.cms.s81c.com/sites/default/files/2022-05-31/Consulting.jpg" alt="Das Bild zeigt Salzbrezeln auf blauem Hintergrund"
#         class=""
#   />
#
#                                                       </div>
#
#     <div class="ibm-card__content ibm-duo-card__content">
#       <div class="ibm-grid-container ibm-pb-3">
#                   <div class="ibm-grid-col-sm-4-4 ibm-grid-col-md-8-6 ibm-grid-col-lg-16-12 ibm-duo-card__heading">
#             <h3 class="bx--type-productive-heading-02 ibm-type-semibold ibm-mb-1 ibm-textcolor-gray-90 ibm-pb-0">
#                   <span > Mit IBM Consulting schneller zum Erfolg</span>
#
#             </h3>
#           </div>
#
#                   <div class="ibm-grid-col-sm-4-4 ibm-grid-col-md-8-6 ibm-grid-col-lg-16-14 ibm-duo-card__desc">
#             <div class="ibm-card__subheading bx--type-body-short-02 ibm-mb-0 ibm-textcolor-gray-70 ibm-pb-0">
#                           <p>Navigieren Sie mit einem Partner Ihres Vertrauens durch eine Geschäftswelt, die nach neuen Regeln funktioniert.</p>
#
#             </div>
#           </div>
#               </div>
#     </div>
#
#           <div class="ibm-card__bottom ibm-duo-card__bottom">
#           <div class="ibm-grid-container">
#             <div class="ibm-grid-col-sm-4-4 ibm-grid-col-md-8-8 ibm-grid-col-lg-16-16">
#
#
#
#
#
#
#
#
#
#     <p class="ibm-duo-u--link-icon ibm-textcolor-blue-60">
#     <span class="ibm-textcolor-blue-60">Setzen wir gemeinsam Ideen in die Tat um</span>
#
#
#
#
#                       <svg focusable="false" class="ibm-duo-u--link-icon--arrow-right" preserveAspectRatio="xMidYMid meet" xmlns="http://www.w3.org/2000/svg" fill="currentColor" aria-hidden="true" aria-label="View this link" width="20" height="20" viewBox="0 0 20 20" slot="icon"><path d="M11.8 2.8L10.8 3.8 16.2 9.3 1 9.3 1 10.7 16.2 10.7 10.8 16.2 11.8 17.2 19 10z"></path></svg>
#
#
#   </p>
#
#             </div>
#           </div>
#       </div>
#
#
#   </a>
#
#     </div>
#
#
#               </div>
#                       <div class="ibm-duo-carousel__item ibm-duo-carousel-1b__item">
#
#
#
#
#
#
#
#
#
#
# <div class="ibm-card ibm-duo-card ibm-duo-card--auto-height ibm-card--noborder ibm-mb-0">
#
#
#
#
#
#
#
#
#
#
#
#     <a  target="_self" href="https://www.ibm.com/de-de/analytics/data-fabric?lnk=dehpv18f5" class="ibm-blocklink ibm-duo-card__link ibm-duo-u--link-icon--rtl ibm-background-cool-gray-10 ibm-duo-card--hover-light">
#
#           <div class="ibm-card__image ibm-duo-card__image ibm-duo-u--ratio--sixteen-nine">
#
#
# <img loading="lazy" src="//1.cms.s81c.com/sites/default/files/2022-08-26/Datafabric.jpg" alt="Kugeln, Scheiben und Daten-Silos in Karos einsortiert"
#         class=""
#   />
#
#                                                       </div>
#
#     <div class="ibm-card__content ibm-duo-card__content">
#       <div class="ibm-grid-container ibm-pb-3">
#                   <div class="ibm-grid-col-sm-4-4 ibm-grid-col-md-8-6 ibm-grid-col-lg-16-12 ibm-duo-card__heading">
#             <h3 class="bx--type-productive-heading-02 ibm-type-semibold ibm-mb-1 ibm-textcolor-gray-90 ibm-pb-0">
#                   <span > Verbinden Sie Ihre Daten – überall</span>
#
#             </h3>
#           </div>
#
#                   <div class="ibm-grid-col-sm-4-4 ibm-grid-col-md-8-6 ibm-grid-col-lg-16-14 ibm-duo-card__desc">
#             <div class="ibm-card__subheading bx--type-body-short-02 ibm-mb-0 ibm-textcolor-gray-70 ibm-pb-0">
#                           <p>Einfacher auf Daten für Analysen und KI zugreifen – um schneller innovativ zu werden</p>
#
#             </div>
#           </div>
#               </div>
#     </div>
#
#           <div class="ibm-card__bottom ibm-duo-card__bottom">
#           <div class="ibm-grid-container">
#             <div class="ibm-grid-col-sm-4-4 ibm-grid-col-md-8-8 ibm-grid-col-lg-16-16">
#
#
#
#
#
#
#
#
#
#     <p class="ibm-duo-u--link-icon ibm-textcolor-blue-60">
#     <span class="ibm-textcolor-blue-60">Sehen Sie, welchen Mehrwert Data Fabric bringt</span>
#
#
#
#
#                       <svg focusable="false" class="ibm-duo-u--link-icon--arrow-right" preserveAspectRatio="xMidYMid meet" xmlns="http://www.w3.org/2000/svg" fill="currentColor" aria-hidden="true" aria-label="View this link" width="20" height="20" viewBox="0 0 20 20" slot="icon"><path d="M11.8 2.8L10.8 3.8 16.2 9.3 1 9.3 1 10.7 16.2 10.7 10.8 16.2 11.8 17.2 19 10z"></path></svg>
#
#
#   </p>
#
#             </div>
#           </div>
#       </div>
#
#
#   </a>
#
#     </div>
#
#
#               </div>
#                       <div class="ibm-duo-carousel__item ibm-duo-carousel-1b__item">
#
#
#
#
#
#
#
#
#
#
# <div class="ibm-card ibm-duo-card ibm-duo-card--auto-height ibm-card--noborder ibm-mb-0">
#
#
#
#
#
#
#
#
#
#
#
#     <a  target="_self" href="https://www.ibm.com/de-de/about/automation?lnk=dehpv18f6" class="ibm-blocklink ibm-duo-card__link ibm-duo-u--link-icon--rtl ibm-background-cool-gray-10 ibm-duo-card--hover-light">
#
#           <div class="ibm-card__image ibm-duo-card__image ibm-duo-u--ratio--sixteen-nine">
#
#
# <img loading="lazy" src="//1.cms.s81c.com/sites/default/files/2022-08-24/Automation.jpg" alt="Spulen durch Fäden verbunden"
#         class=""
#   />
#
#                                                       </div>
#
#     <div class="ibm-card__content ibm-duo-card__content">
#       <div class="ibm-grid-container ibm-pb-3">
#                   <div class="ibm-grid-col-sm-4-4 ibm-grid-col-md-8-6 ibm-grid-col-lg-16-12 ibm-duo-card__heading">
#             <h3 class="bx--type-productive-heading-02 ibm-type-semibold ibm-mb-1 ibm-textcolor-gray-90 ibm-pb-0">
#                   <span > Stellen Sie Ihre Anwendungen auf Autopilot</span>
#
#             </h3>
#           </div>
#
#                   <div class="ibm-grid-col-sm-4-4 ibm-grid-col-md-8-6 ibm-grid-col-lg-16-14 ibm-duo-card__desc">
#             <div class="ibm-card__subheading bx--type-body-short-02 ibm-mb-0 ibm-textcolor-gray-70 ibm-pb-0">
#                           <p>Investitionen in AIOps und Automatisierung können Ihre Kosten um 50 % reduzieren.</p>
#
#             </div>
# ...
#       </div>
#     </div>
#
#
#     </div>
#   </div>
#
#
#                 </div>
#                           <div class="ibm-duo-carousel__item ibm-duo-carousel-2b__item">
#
#
#
#
#
#
# <div class="ibm-card ibm-duo-card ibm-card--noborder ibm-mb-0">
#
#
#       <div class="ibm-blocklink ibm-duo-card__link ibm-background-cool-gray-10">
#           <div class="ibm-card__content ibm-duo-card__content">
#       <div class="ibm-grid-container">
#         <div class="ibm-grid-col-sm-4-4 ibm-grid-col-md-8-7 ibm-grid-col-lg-16-14 ibm-pb-4">
#
#
#
#                       <div class="bx--type-body-long-02 ibm-textcolor-gray-70 ibm-mb-3 ibm-duo-card__desc">
#                           <p><strong> Trendsetzende Technologien</strong><br />
#  </p>
#
# <ul><li><a href="/de-de/cloud/hybrid?lnk=hpv18ct20">Hybrid Cloud</a></li>
# 	<li><a href="/cloud/learn/public-cloud?lnk=hpv18ct1">Public Cloud</a></li>
# 	<li><a href="/de-de/cloud/redhat?lnk=hpv18ct13">Red Hat</a></li>
# 	<li><a href="/de-de/watson?lnk=hpv18ct3">Künstliche Intelligenz</a></li>
# 	<li><a href="https://www.ibm.com/de-de/quantum-computing?lnk=hpv18ct18">Quantencomputing</a></li>
# 	<li><a href="/cloud/learn/kubernetes?lnk=hpv18ct8">Kubernetes</a></li>
# 	<li><a href="/de-de/products/spss-statistics?lnk=ushpv18ct7">SPSS</a></li>
# 	<li><a href="/de-de/blockchain?lnk=hpv18ct1">Blockchain</a></li>
# 	<li><a href="https://www.ibm.com/de-de/employment?lnk=hpv18ct2">Karriere</a></li>
# </ul>
#
#             </div>
#                   </div>
#       </div>
#     </div>
#
#
#     </div>
#   </div>
#
#
#                 </div>
#                         <span class="ibm-duo-carousel__counter ibm-duo-carousel__counter--3 bx--type-body-long-01 ibm-mb-1 ibm-textcolor-gray-90"></span>
#
#                           <button type="button" class="slick-arrow slick-next" data-ibm-cm-avoid="true">
#       <svg focusable="false" preserveAspectRatio="xMidYMid meet" xmlns="http://www.w3.org/2000/svg" width="32" height="32" viewBox="0 0 32 32" aria-hidden="true" aria-label="Show next content"><polygon points="22,16 12,26 10.6,24.6 19.2,16 10.6,7.4 12,6"></polygon></svg>
# </button>
#                       </div>
#         </div>
#
#     </div>
#   </section>
#
#
#
#
#
#
#
#   <section  role="article" about="/de-de/node/2598824" id="2598824" class="ibm-duo-band ibm-duo-module-11a-double ibm-background-gray-100" data-bg-lazy-load>
#           <div class="ibm-grid-container" data-widget="setsameheight" data-always="true" data-items=".ibm-duo-module-11a-double__headline">
#                   <div class="ibm-grid-col-sm-4-4 ibm-grid-col-md-8-4 ibm-grid-col-lg-16-8 ibm-grid-col-seamless">
#
#
#
#
#
# <div class="ibm-duo-module-11a-double ibm-duo-module-11a-double__item ibm-background-gray-100">
#       <div class="ibm-duo-module-11a-double__bg  ani-reveal ani-fadeInUp" style="background-image:url('//1.cms.s81c.com/sites/default/files/2022-06-22/Mainz-800x800_0.jpg')" role="img" aria-label="Das Bild zeigt eine Frau mit Mundschutz im Labor"></div>
#
#   <div class="ibm-grid-container ibm-duo-module-11a-double__content">
#     <div class="ibm-grid-col-sm-4-4 ibm-grid-col-md-8-8 ibm-grid-col-lg-16-10">
#               <div class="ibm-grid-col-sm-4-3 ibm-grid-col-md-8-6 ibm-grid-col-lg-16-16 ibm-grid-col-seamless">
#           <h2 class="bx--type-expressive-heading-05 ibm-type-light ibm-textcolor-gray-10 ibm-mb-3 ibm-pb-0 ibm-duo-module-11a-double__headline ani-reveal ani-fadeInUp">
#                 <span > Das Beste aus zwei Welten</span>
#
#           </h2>
#         </div>
#
#               <div class="ibm-grid-col-sm-4-3 ibm-grid-col-md-8-6 ibm-grid-col-lg-16-12 ibm-grid-col-seamless">
#           <div class="bx--type-body-long-02 ibm-textcolor-gray-30 ibm-mb-0 ibm-duo-module-11a-double__subhead ibm-pb-1 ani-reveal ani-fadeInUp">
#                         <p>Sicherheit und Agilität kommen für das Universitätsklinikum Mainz zusammen</p>
#
#           </div>
#         </div>
#           </div>
#   </div>
#
#       <div class="ibm-duo-module-11a-double__cta">
#       <div class="ibm-grid-container">
#         <div class="ibm-grid-col-sm-4-2 ibm-grid-col-md-8-4 ibm-grid-col-lg-16-8"></div>
#         <div class="ibm-grid-col-sm-4-2 ibm-grid-col-md-8-4 ibm-grid-col-lg-16-8 ibm-duo-module-11a-double__cta-wrapper">
#
#
#
#
#
#
#
#
#
#
#   <a  target="_self" href="https://www.ibm.com/case-studies/university-of-mainz-medical-center/de-de/?lnk=hpv18cs1" class="ibm-duo-cta ani-reveal ani-fadeInUp">
#     <p class='ibm-type-e ibm-textcolor-white-core ibm-p ibm-mb-0'>Sehen Sie sich an, wie Lösungen in vier Monaten entwickelt wurden</p>
#     <div class="ibm-duo-u--link-icon">
#
#
#
#
#                       <svg focusable="false" class="ibm-duo-u--link-icon--arrow-right" preserveAspectRatio="xMidYMid meet" xmlns="http://www.w3.org/2000/svg" fill="currentColor" aria-hidden="true" aria-label="View this link" width="20" height="20" viewBox="0 0 20 20" slot="icon"><path d="M11.8 2.8L10.8 3.8 16.2 9.3 1 9.3 1 10.7 16.2 10.7 10.8 16.2 11.8 17.2 19 10z"></path></svg>
#
#
#     </div>
#   </a>
#
#
#         </div>
#       </div>
#     </div>
#   </div>
#
#
#             </div>
#                   <div class="ibm-grid-col-sm-4-4 ibm-grid-col-md-8-4 ibm-grid-col-lg-16-8 ibm-grid-col-seamless">
#
#
#
#
#
# <div class="ibm-duo-module-11a-double ibm-duo-module-11a-double__item ibm-background-gray-100">
#       <div class="ibm-duo-module-11a-double__bg  ani-reveal ani-fadeInUp" style="background-image:url('//1.cms.s81c.com/sites/default/files/2021-02-26/cs-hub-logos-1042x1130.png')" role="img" aria-label="Logos verschiedener IBM Kunden"></div>
#
#   <div class="ibm-grid-container ibm-duo-module-11a-double__content">
#     <div class="ibm-grid-col-sm-4-4 ibm-grid-col-md-8-8 ibm-grid-col-lg-16-10">
#               <div class="ibm-grid-col-sm-4-3 ibm-grid-col-md-8-6 ibm-grid-col-lg-16-16 ibm-grid-col-seamless">
#           <h2 class="bx--type-expressive-heading-05 ibm-type-light ibm-textcolor-gray-10 ibm-mb-3 ibm-pb-0 ibm-duo-module-11a-double__headline ani-reveal ani-fadeInUp">
#                 <span > Weitere Kundenreferenzen</span>
#
#           </h2>
#         </div>
#
#               <div class="ibm-grid-col-sm-4-3 ibm-grid-col-md-8-6 ibm-grid-col-lg-16-12 ibm-grid-col-seamless">
#           <div class="bx--type-body-long-02 ibm-textcolor-gray-30 ibm-mb-0 ibm-duo-module-11a-double__subhead ibm-pb-1 ani-reveal ani-fadeInUp">
#                         <p>IBM unterstützt Unternehmen in allen Branchen und weltweit dabei, ihre Ziele zu erreichen</p>
#
#           </div>
#         </div>
#           </div>
#   </div>
#
#       <div class="ibm-duo-module-11a-double__cta">
#       <div class="ibm-grid-container">
#         <div class="ibm-grid-col-sm-4-2 ibm-grid-col-md-8-4 ibm-grid-col-lg-16-8"></div>
#         <div class="ibm-grid-col-sm-4-2 ibm-grid-col-md-8-4 ibm-grid-col-lg-16-8 ibm-duo-module-11a-double__cta-wrapper">
#
#
#
#
#
#
#
#
#
#
#   <a  target="_self" href="/case-studies/search?lnk=hpv18cs2" class="ibm-duo-cta ani-reveal ani-fadeInUp">
#     <p class='ibm-type-e ibm-textcolor-white-core ibm-p ibm-mb-0'>Sehen Sie sich an, wie IBM Technologie echte Lösungen vorantreibt</p>
#     <div class="ibm-duo-u--link-icon">
#
#
#
#
#                       <svg focusable="false" class="ibm-duo-u--link-icon--arrow-right" preserveAspectRatio="xMidYMid meet" xmlns="http://www.w3.org/2000/svg" fill="currentColor" aria-hidden="true" aria-label="View this link" width="20" height="20" viewBox="0 0 20 20" slot="icon"><path d="M11.8 2.8L10.8 3.8 16.2 9.3 1 9.3 1 10.7 16.2 10.7 10.8 16.2 11.8 17.2 19 10z"></path></svg>
#
#
#     </div>
#   </a>
#
#
#         </div>
#       </div>
#     </div>
#   </div>
#
#
#             </div>
#               <div>
#       </section>
#
#
#           </div>
#
#         </div>       </div>     </div>   </div> </main>
#
#   </div>
#
#   </div>
#
#   </div>
#     <footer role="contentinfo" aria-label="IBM">
#       <div class="region region-footer">
#
#
# <div id="ibm-footer-module">
#     <section role="region" aria-label="Resources">
#
#             <div class="ibm-columns">
#                   <div class="ibm-footermenu-list ibm-col-4-1" aria-label="Informationen">
#             <h3 class="ibm-bold">Informationen</h3>
#             <ul class="ibm-plain-list">
#                               <li><a href="https://www.ibm.com/de-de/products/?lnk=fdi">Produkte</a></li>
#                               <li><a href="https://www.ibm.com/de-en/products/trials?lnk=STW_DE_HPF_THP_FT_TL&amp;lnk2=goto_THP">Kostenlose Testversionen</a></li>
#                               <li><a href="https://www.ibm.com/de-de/products/?lnk=hmmpr">Rabatte</a></li>
#                               <li><a href="https://www.ibm.com/de-de/services?lnk=fdi-dede">Services</a></li>
#                               <li><a href="https://www.ibm.com/de-de/industries">Branchen</a></li>
#                               <li><a href="https://www.ibm.com/ibm/clientreference/us/en/?lnk=fdi-dede">Kundenreferenzen</a></li>
#                               <li><a href="https://www.ibm.com/de-de/events?lnk=fdi-dede">Events</a></li>
#                               <li><a href="https://www.ibm.com/blogs/think/de-de/?lnk=fdi-dede">IBM THINK Blog</a></li>
#                               <li><a href="https://www.ibm.com/de-de/financing">Finanzierung</a></li>
#                           </ul>
#           </div>
#                   <div class="ibm-footermenu-list ibm-col-4-1" aria-label="Informationen für ...">
#             <h3 class="ibm-bold">Informationen für ...</h3>
#             <ul class="ibm-plain-list">
#                               <li><a href="https://developer.ibm.com/?lnk=fif-dede">Entwickler</a></li>
#                               <li><a href="https://www.ibm.com/de-de/partnerworld/public">IBM Business Partner</a></li>
#                               <li><a href="https://www.ibm.com/partners/start/?lnk=fif-dede">Neupartner (Startangebote)</a></li>
#                           </ul>
#           </div>
#                   <div class="ibm-footermenu-list ibm-col-4-1" aria-label="Kontakt mit IBM">
#             <h3 class="ibm-bold">Kontakt mit IBM</h3>
#             <ul class="ibm-plain-list">
#                               <li><a href="https://www.ibm.com/consulting/de-de/">IBM Consulting</a></li>
#                               <li><a href="https://www.ibm.com/mysupport/s/?language=en_US">Support</a></li>
#                               <li><a href="https://www.ibm.com/partnerworld/public">Business Partner</a></li>
#                               <li><a href="https://myibm.ibm.com/dashboard/?lnk=mmi_dede">Meine IBM</a></li>
#                           </ul>
#           </div>
#                   <div class="ibm-footermenu-list ibm-col-4-1" aria-label="IBM in Deutschland">
#             <h3 class="ibm-bold">IBM in Deutschland</h3>
#             <ul class="ibm-plain-list">
#                               <li><a href="https://www.ibm.com/ibm/clientcenter/walldorf?lnk=fab-dede">IBM Innovation Center for SAP® Solutions</a></li>
#                               <li><a href="https://www.ibm.com/de-de/employment/?lnk=fab-dede">Karriere</a></li>
#                               <li><a href="https://de.newsroom.ibm.com/">Newsroom</a></li>
#                               <li><a href="https://www.ibm.com/investor/?lnk=fab-dede">Investor-Relations</a></li>
#                               <li><a href="https://www.ibm.com/de-de/about?lnk=fab-dede">IBM in Deutschland</a></li>
#                               <li><a href="https://www.ibm.com/ibm/clientcenter/boeblingen/">IBM Client Center Böblingen</a></li>
#                               <li><a href="https://www.ibm.com/business-operations/resources/munich-center">IBM Watson Center Munich</a></li>
#                           </ul>
#           </div>
#               </div>
#
#
#     </section>
#
# </div>
#
#
# <div id="ibm-footer">
#
#     <div class="ibm-columns">
#       <div class="ibm-col-1-1">
#                   <div class="ibm-footer-corporate-links">
#             <ul>
#                               <li>
#                   <a href="https://www.ibm.com/de-de/about?lnk=flg-cont-dede">Kontakt</a>
#                 </li>
#                               <li>
#                   <a href="https://www.ibm.com/de-de/privacy?lnk=flg-priv-dede">Datenschutz</a>
#                 </li>
#                               <li>
#                   <a href="https://www.ibm.com/de-de/legal?lnk=flg-tous-dede">Nutzungsbedingungen</a>
#                 </li>
#                               <li>
#                   <a href="https://www.ibm.com/able/?lnk=flg-able-dede">Barrierefreiheit</a>
#                 </li>
#                               <li>
#                   <a href="https://www.ibm.com/de-de/about?lnk=flg">Impressum</a>
#                 </li>
#                             <li id="ibm-truste-cp">
#                 <a href="#" onclick="truste.eu.clickListener();return false;">Cookie Präferenzen</a>
#               </li>
#             </ul>
#           </div>
#
#                 </div>
#     </div>
#
# </div>
#
#   </div>
#
#   </footer>
#
# </div>
#
#   </div>
#
#
#     <script type="application/json" data-drupal-selector="drupal-settings-json">{"path":{"baseUrl":"\/","scriptPath":null,"pathPrefix":"de-de\/","currentPath":"node\/2598578","currentPathIsAdmin":false,"isFront":false,"currentLanguage":"de-de"},"pluralDelimiter":"\u0003","suppressDeprecationErrors":true,"ajaxPageState":{"libraries":"hc_fractal\/01-1b,hc_fractal\/02-2b,hc_fractal\/05-5e,hc_fractal\/11-11a-double,hc_fractal\/12-12a,hc_fractal\/animations,hc_fractal\/card,hc_fractal\/card-image,hc_fractal\/full-width-double,hc_fractal\/full-width-text,hc_fractal\/heading,hc_fractal\/image,hc_fractal\/main_css,hc_fractal\/main_js,hc_fractal\/picturefill_background,hc_fractal\/slick,ibm_ckeditor\/ibm_ckeditor_table_style,ibm_duo\/ibm_duo,ibm_tmgmt_concurrency\/ibm_tmgmt_concurrency_messaging,ibm_tmgmt_concurrency\/ibm_tmgmt_concurrency_publisher,ibm_tmgmt_concurrency\/ibm_tmgmt_concurrency_publisher_finish,metadata\/focus_area,northstar\/font,northstar\/grid-fluid,northstar\/shame,northstar\/stats,northstar\/tables,system\/base,tactic_codes\/tactic_codes","theme":"ibm_duo","theme_token":"P91gny7471v3ccQQ6u5J0sSJoY9Z0l6mjD6qly2q_S8"},"ajaxTrustedUrl":[],"ibm_tmgmt_concurrency_publisher":{"nid":"2598578","language":"de-de","submit_button":"#edit-submit","form":"#content-moderation-entity-moderation-form","route":"entity.node.canonical"},"user":{"uid":0,"permissionsHash":"0c916a5a867aea2de154565fb888afbc951fd70dccc6e1340a5947a9a777e51e"}}</script>
# <script src="//1.cms.s81c.com/sites/default/files/js/js_FCwHc1hIJuAt5v0Yks_WU_DIbLLmuPnRuA8WNaDgtLQ.js"></script>
# <script src="//www.ibm.com/common/digitaladvisor/cm-app/latest/cm-app.min.js" defer></script>
# <script src="//1.www.s81c.com/common/v18/drupal/js/tables.js" defer></script>
# <script src="//1.cms.s81c.com/modules/contrib/hc_fractal/dist/js/interactions.js?v=1.1.11" defer></script>
# <script src="//1.cms.s81c.com/modules/contrib/hc_fractal/dist/js/background-image-lazy-load.js?v=1.1.11" defer></script>
# <script src="//1.cms.s81c.com/modules/contrib/hc_fractal/dist/js/v18-widgets.js?v=1.1.11" defer></script>
# <script src="//1.www.s81c.com/common/js/tactic.js" defer></script>
# <script src="//1.www.s81c.com/common/js/tacticbindlinks.js" defer></script>
# <script src="//1.cms.s81c.com/sites/default/files/js/js_BRA5GjSDQY6Bvtcfnd7MymhklYPqPv2yNfHseaJIdo4.js"></script>
# <script src="//1.cms.s81c.com/modules/contrib/hc_fractal/dist/js/slick-sliders.js?v=1.1.18" defer></script>
# <script src="//1.cms.s81c.com/modules/contrib/hc_fractal/dist/js/plugins/picturefill-background.js?v=1.1.10" defer></script>
#
#       <script type="text/javascript"  src="/roRJf45Ii/h/SpLaji5Q/kYum4Xpwa5/bgAfAQ/UzMpf/UVQPzI"></script><link rel="stylesheet" type="text/css"  href="/_sec/cp_challenge/sec-3-8.css">
#           <script  src="/_sec/cp_challenge/sec-cpt-3-8.js" async defer></script>
#           <div id="sec-overlay" style="display:none;">
#           <div id="sec-container">
#           </div>
#         </div></body>
# </html>

# %% [markdown]
# Create a soup object using the class BeautifulSoup

# %%
soup = BeautifulSoup(data,"html5lib")  # create a soup object using the variable 'data'

# %% [markdown]
# Scrape all links

# %%
for link in soup.find_all('a'):  # in html anchor/link is represented by the tag <a>
    print(link.get('href'))
# Out:
# https://www.ibm.com/de/de
# https://www.ibm.com/lets-create/de-de?lnk=hpmlc
#
# https://www.ibm.com/de-de/products?lnk=hpmps_bupr_dede&lnk2=link
# https://www.ibm.com/de-de/industries?lnk=hpmps_buin_dede&lnk2=link
# https://www.ibm.com/de-de/watson?lnk=hpmps_buai_dede&lnk2=link
# https://www.ibm.com/de-de/about/automation?lnk=hpmps_buau_dede&lnk2=link
# https://www.ibm.com/de-de/blockchain?lnk=hpmps_bubc_dede&lnk2=link
# https://www.ibm.com/de-de/business-operations?lnk=hpmps_buop_dede&lnk2=link
# https://www.ibm.com/de-de/cloud?lnk=hpmps_bucl_dede&lnk2=link
# https://www.ibm.com/de-de/analytics?lnk=hpmps_buda_dede&lnk2=link
# https://www.ibm.com/de-de/it-infrastructure?lnk=hpmps_buit_dede&lnk2=link
# https://www.ibm.com/de-de/security?lnk=hpmps_buse_dede&lnk2=link
# https://www.ibm.com/de-de/supply-chain?lnk=hpmps_busc_dede&lnk2=link
# https://www.ibm.com/de-de/financing?lnk=hpmps_bufi_dede&lnk2=link
# https://www.ibm.com/de-de/products?lnk=hpmps_buall_dede&lnk2=link
#
# https://www.ibm.com/consulting/de-de/?lnk=hpmsc_buco_dede&lnk2=learn
# https://www.ibm.com/de-de/services/business?lnk=hpmsc_bups_dede&lnk2=link
# https://www.ibm.com/de-de/services?lnk=hpmsc_budbs_dede&lnk2=link
# https://www.ibm.com/de-de/cloud/services?lnk=hpmsc_buhs_dede
# https://www.ibm.com/de-de/services/talent-management?lnk=hpmsc_buta_dede&lnk2=link
# https://www.ibm.com/de-de/services/applications?lnk=hpmsc_buas_dede&lnk2=link
# https://www.ibm.com/de-de/garage?lnk=hpmsc_buas_dede&lnk2=link
# https://www.ibm.com/de-de/security/services?lnk=hpmsc_buse_dede&lnk2=link
# https://www.ibm.com/de-de/services/technology-support?lnk=hpmsc_busv_dede&lnk2=link
# https://www.ibm.com/de-de/financing?lnk=hpmsc_bufi_dede&lnk2=link
# https://www.ibm.com/de-de/services?lnk=hpmsc_buall_dede&lnk2=link
#
# https://www.ibm.com/support/de/de/?lnk=hpmls_busu_dede&lnk2=link
# https://www.ibm.com/support/knowledgecenter/?lnk=hpmls_budc_dede&lnk2=link
# https://developer.ibm.com/?lnk=hpmls_bude_dede&lnk2=link
# https://www.ibm.com/training/?lnk=hpmls_butr_dede&lnk2=link
# https://www.ibm.com/blogs/?lnk=hpmls_bure_dede&lnk2=link
# https://www.ibm.com/de-de/cloud/learn?lnk=hpmls_buwi_dede&lnk2=link
#
# https://www.ibm.com/de-de/partnerworld/public?lnk=hpmex_bupa_dede&lnk2=link
# https://www.research.ibm.com/?lnk=hpmex_bure_dede&lnk2=link
# https://www.ibm.com/de-de/about?lnk=hpmex_buab_dede&lnk2=link
# https://www.ibm.com/de-de/impact/covid-19?lnk=hpmex_buco_dede&lnk2=link
# https://www.ibm.com/sitemap/de/de
# https://www.ibm.com/de-de/events/think/pop-up-wien?lnk=dehpv18l1
# https://www.ibm.com/de-de/events/think/pop-up-koeln?lnk=dehpv18l2
# https://de.newsroom.ibm.com/2022-07-27-Cost-of-a-Data-Breach-Studie-2022?lnk=dehpv18nf1
# https://www.ibm.com/de-de/events/turn-vision-into-action?lnk=dehpv18f1
# https://www.ibm.com/de-de/consulting/resources/design-data-led-experience-transformation?lnk=dehpv18f2
# https://www.ibm.com/de-de/it-infrastructure/power?lnk=dehpv18f3
# https://www.ibm.com/consulting/de-de?lnk=dehpv18f4
# https://www.ibm.com/de-de/analytics/data-fabric?lnk=dehpv18f5
# https://www.ibm.com/de-de/about/automation?lnk=dehpv18f6
# /de-de/products/offers-and-discounts?lnk=STW_DE_HPT_TL&psrc=NONE&pexp=DEF&lnk2=goto_MPDISC
# https://www.ibm.com/de-de/cloud/cloud-pak-for-automation?lnk=STW_DE_HP_D1_TL&psrc=NONE&pexp=DEF&lnk2=trial_PHP
# https://www.ibm.com/de-de/verify/verify-identity?lnk=STW_DE_HP_D2_TL&psrc=NONE&pexp=DEF&lnk2=trial_PHP
# https://www.ibm.com/de-de/products/watson-assistant?lnk=STW_DE_HP_D3_TL&psrc=NONE&pexp=DEF&lnk2=trial_PHP
# https://www.ibm.com/de-de/products/unified-endpoint-management?lnk=STW_DE_HPT_T4_BLK&lnk2=trial_MaaS360Wat&psrc=none&pexp=def
# https://www.ibm.com/de-de/products/cognos-analytics?lnk=STW_DE_HPT_T5_BLK&lnk2=trial_%20CogAnalytics%20&psrc=none&pexp=def
# https://www.ibm.com/de-de/cloud/vmware/shared?lnk=STW_DE_HPT_T6_BLK&lnk2=trial_VMware&psrc=none&pexp=def
# https://developer.ibm.com/depmodels/cloud/?lnk=hpv18ct16
# https://developer.ibm.com/technologies/artificial-intelligence?lnk=hpv18ct19
# https://developer.ibm.com/?lnk=hpv18ct9
# https://www.ibm.com/docs/en?lnk=hpv18ct14
# https://www.redbooks.ibm.com/?lnk=ushpv18ct10
# https://www.ibm.com/support/home/?lnk=hpv18ct11
# https://www.ibm.com/training/?lnk=hpv18ct15
# /de-de/cloud/hybrid?lnk=hpv18pt14
# /cloud/learn/public-cloud?lnk=hpv18ct1
# /de-de/watson?lnk=ushpv18pt17
# /de-de/garage?lnk=hpv18pt13
# /de-de/blockchain?lnk=hpv18pt4
# https://www.ibm.com/thought-leadership/institute-business-value/?lnk=hpv18pt12
# /de-de/analytics?lnk=hpv18pt1
# /de-de/security?lnk=hpv18pt9
# /de-de/financing?lnk=hpv18pt3
# https://www.ibm.com/de-de/quantum-computing?lnk=hpv18pt16
# /de-de/cloud/hybrid?lnk=hpv18ct20
# /cloud/learn/public-cloud?lnk=hpv18ct1
# /de-de/cloud/redhat?lnk=hpv18ct13
# /de-de/watson?lnk=hpv18ct3
# https://www.ibm.com/de-de/quantum-computing?lnk=hpv18ct18
# /cloud/learn/kubernetes?lnk=hpv18ct8
# /de-de/products/spss-statistics?lnk=ushpv18ct7
# /de-de/blockchain?lnk=hpv18ct1
# https://www.ibm.com/de-de/employment?lnk=hpv18ct2
# https://www.ibm.com/case-studies/university-of-mainz-medical-center/de-de/?lnk=hpv18cs1
# /case-studies/search?lnk=hpv18cs2
# https://www.ibm.com/de-de/products/?lnk=fdi
# https://www.ibm.com/de-en/products/trials?lnk=STW_DE_HPF_THP_FT_TL&lnk2=goto_THP
# https://www.ibm.com/de-de/products/?lnk=hmmpr
# https://www.ibm.com/de-de/services?lnk=fdi-dede
# https://www.ibm.com/de-de/industries
# https://www.ibm.com/ibm/clientreference/us/en/?lnk=fdi-dede
# https://www.ibm.com/de-de/events?lnk=fdi-dede
# https://www.ibm.com/blogs/think/de-de/?lnk=fdi-dede
# https://www.ibm.com/de-de/financing
# https://developer.ibm.com/?lnk=fif-dede
# https://www.ibm.com/de-de/partnerworld/public
# https://www.ibm.com/partners/start/?lnk=fif-dede
# https://www.ibm.com/consulting/de-de/
# https://www.ibm.com/mysupport/s/?language=en_US
# https://www.ibm.com/partnerworld/public
# https://myibm.ibm.com/dashboard/?lnk=mmi_dede
# https://www.ibm.com/ibm/clientcenter/walldorf?lnk=fab-dede
# https://www.ibm.com/de-de/employment/?lnk=fab-dede
# https://de.newsroom.ibm.com/
# https://www.ibm.com/investor/?lnk=fab-dede
# https://www.ibm.com/de-de/about?lnk=fab-dede
# https://www.ibm.com/ibm/clientcenter/boeblingen/
# https://www.ibm.com/business-operations/resources/munich-center
# https://www.ibm.com/de-de/about?lnk=flg-cont-dede
# https://www.ibm.com/de-de/privacy?lnk=flg-priv-dede
# https://www.ibm.com/de-de/legal?lnk=flg-tous-dede
# https://www.ibm.com/able/?lnk=flg-able-dede
# https://www.ibm.com/de-de/about?lnk=flg
# #

# %% [markdown]
# Scrape  all images

# %%
for link in soup.find_all('img'):# in html image is represented by the tag <img>
    print(link.get('src'))
# Out:
# //1.cms.s81c.com/sites/default/files/2022-08-10/IBM_Turn_Vision_into_Action_2022-Webpage-444x254px.jpeg
# //1.cms.s81c.com/sites/default/files/2022-08-16/20220815-consulting-design-data-led-experience-transformation-26852-444x33-444x254.jpg
# //1.cms.s81c.com/sites/default/files/2022-08-25/Power10-card-444x254.jpg
# //1.cms.s81c.com/sites/default/files/2022-05-31/Consulting.jpg
# //1.cms.s81c.com/sites/default/files/2022-08-26/Datafabric.jpg
# //1.cms.s81c.com/sites/default/files/2022-08-24/Automation.jpg
# //1.cms.s81c.com/sites/default/files/2022-07-29/Cloud-Pak-for-Automation-trial-XS-444x256.png
# //1.cms.s81c.com/sites/default/files/2022-07-29/Security-Verify-Trial-800x450_s_444x256.jpg
# //1.cms.s81c.com/sites/default/files/2022-07-29/20220216-t-ibm-watson-assistant_s_444x256.png
# //1.cms.s81c.com/sites/default/files/2021-12-02/10072019-t-bt-MaaS360-watson-23210-700x420.png
# //1.cms.s81c.com/sites/default/files/2022-02-10/Cognos-Analytics-20626-700x420.png
# //1.cms.s81c.com/sites/default/files/2021-12-02/IBM-Cloud-23059-700x420.png

# %% [markdown]
# ## Scrape data from html tables

# %%
#The below url contains a html table with data about colors and color codes.

# %%
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html"

# %% [markdown]
# Before proceeding to scrape a web site, you need to examine the contents, and the way data is organized on the website. Open the above url in your browser and check how many rows and columns are there in the color table.

# %%
# get the contents of the webpage in text format and store in a variable called data
data  = requests.get(url).text
print(data)
# Out:
# <html>
#    <body>
#       <h1>Partital List  of HTML5 Supported Colors</h1>
# <table border ="1" class="main-table">
#    <tr>
#       <td>Number </td>
#       <td>Color</td>
#       <td>Color Name</td>
#       <td>Hex Code<br>#RRGGBB</td>
#       <td>Decimal Code<br>(R,G,B)</td>
#    </tr>
#    <tr>
#       <td>1</td>
#       <td style="background:lightsalmon;">&nbsp;</td>
#       <td>lightsalmon</td>
#       <td>#FFA07A</td>
#       <td>rgb(255,160,122)</td>
#    </tr>
#    <tr>
#       <td>2</td>
#       <td style="background:salmon;">&nbsp;</td>
#       <td>salmon</td>
#       <td>#FA8072</td>
#       <td>rgb(250,128,114)</td>
#    </tr>
#    <tr>
#       <td>3</td>
#       <td style="background:darksalmon;">&nbsp;</td>
#       <td>darksalmon</td>
#       <td>#E9967A</td>
#       <td>rgb(233,150,122)</td>
#    </tr>
#    <tr>
#       <td>4</td>
#       <td style="background:lightcoral;">&nbsp;</td>
#       <td>lightcoral</td>
#       <td>#F08080</td>
#       <td>rgb(240,128,128)</td>
#    </tr>
#    <tr>
#       <td>5</td>
#       <td style="background:coral;">&nbsp;</td>
#       <td>coral</td>
#       <td>#FF7F50</td>
#       <td>rgb(255,127,80)</td>
#    </tr>
#    <tr>
#       <td>6</td>
#       <td style="background:tomato;">&nbsp;</td>
#       <td>tomato</td>
#       <td>#FF6347</td>
#       <td>rgb(255,99,71)</td>
#    </tr>
#    <tr>
#       <td>7</td>
#       <td style="background:orangered;">&nbsp;</td>
#       <td>orangered</td>
#       <td>#FF4500</td>
#       <td>rgb(255,69,0)</td>
#    </tr>
#    <tr>
#       <td>8</td>
#       <td style="background:gold;">&nbsp;</td>
#       <td>gold</td>
#       <td>#FFD700</td>
#       <td>rgb(255,215,0)</td>
#    </tr>
#    <tr>
#       <td>9</td>
#       <td style="background:orange;">&nbsp;</td>
#       <td>orange</td>
#       <td>#FFA500</td>
#       <td>rgb(255,165,0)</td>
#    </tr>
#    <tr>
#       <td>10</td>
#       <td style="background:darkorange;">&nbsp;</td>
#       <td>darkorange</td>
#       <td>#FF8C00</td>
#       <td>rgb(255,140,0)</td>
#    </tr>
#    <tr>
#       <td>11</td>
#       <td style="background:lightyellow;">&nbsp;</td>
#       <td>lightyellow</td>
#       <td>#FFFFE0</td>
#       <td>rgb(255,255,224)</td>
#    </tr>
#    <tr>
#       <td>12</td>
#       <td style="background:lemonchiffon;">&nbsp;</td>
#       <td>lemonchiffon</td>
#       <td>#FFFACD</td>
#       <td>rgb(255,250,205)</td>
#    </tr>
#    <tr>
#       <td>13</td>
#       <td style="background:papayawhip;">&nbsp;</td>
#       <td>papayawhip</td>
#       <td>#FFEFD5</td>
#       <td>rgb(255,239,213)</td>
#    </tr>
#    <tr>
#       <td>14</td>
#       <td style="background:moccasin;">&nbsp;</td>
#       <td>moccasin</td>
#       <td>#FFE4B5</td>
#       <td>rgb(255,228,181)</td>
#    </tr>
#    <tr>
#       <td>15</td>
#       <td style="background:peachpuff;">&nbsp;</td>
#       <td>peachpuff</td>
#       <td>#FFDAB9</td>
#       <td>rgb(255,218,185)</td>
#    </tr>
#    <tr>
#       <td>16</td>
#       <td style="background:palegoldenrod;">&nbsp;</td>
#       <td>palegoldenrod</td>
#       <td>#EEE8AA</td>
#       <td>rgb(238,232,170)</td>
#    </tr>
#    <tr>
#       <td>17</td>
#       <td style="background:khaki;">&nbsp;</td>
#       <td>khaki</td>
#       <td>#F0E68C</td>
#       <td>rgb(240,230,140)</td>
#    </tr>
#    <tr>
#       <td>18</td>
#       <td style="background:darkkhaki;">&nbsp;</td>
#       <td>darkkhaki</td>
#       <td>#BDB76B</td>
#       <td>rgb(189,183,107)</td>
#    </tr>
#    <tr>
#       <td>19</td>
#       <td style="background:yellow;">&nbsp;</td>
#       <td>yellow</td>
#       <td>#FFFF00</td>
#       <td>rgb(255,255,0)</td>
#    </tr>
#    <tr>
#       <td>20</td>
#       <td style="background:lawngreen;">&nbsp;</td>
#       <td>lawngreen</td>
#       <td>#7CFC00</td>
#       <td>rgb(124,252,0)</td>
#    </tr>
#    <tr>
#       <td>21</td>
#       <td style="background:chartreuse;">&nbsp;</td>
#       <td>chartreuse</td>
#       <td>#7FFF00</td>
#       <td>rgb(127,255,0)</td>
#    </tr>
#    <tr>
#       <td>22</td>
#       <td style="background:limegreen;">&nbsp;</td>
#       <td>limegreen</td>
#       <td>#32CD32</td>
#       <td>rgb(50,205,50)</td>
#    </tr>
#    <tr>
#       <td>23</td>
#       <td style="background:lime;">&nbsp;</td>
#       <td>lime</td>
#       <td>#00FF00</td>
#       <td>rgb(0.255.0)</td>
#    </tr>
#    <tr>
#       <td>24</td>
#       <td style="background:forestgreen;">&nbsp;</td>
#       <td>forestgreen</td>
#       <td>#228B22</td>
#       <td>rgb(34,139,34)</td>
#    </tr>
#    <tr>
#       <td>25</td>
#       <td style="background:green;">&nbsp;</td>
#       <td>green</td>
#       <td>#008000</td>
#       <td>rgb(0,128,0)</td>
#    </tr>
#    <tr>
#       <td>26</td>
#       <td style="background:powderblue;">&nbsp;</td>
#       <td>powderblue</td>
#       <td>#B0E0E6</td>
#       <td>rgb(176,224,230)</td>
#    </tr>
#    <tr>
#       <td>27</td>
#       <td style="background:lightblue;">&nbsp;</td>
#       <td>lightblue</td>
#       <td>#ADD8E6</td>
#       <td>rgb(173,216,230)</td>
#    </tr>
#    <tr>
#       <td>28</td>
#       <td style="background:lightskyblue;">&nbsp;</td>
#       <td>lightskyblue</td>
#       <td>#87CEFA</td>
#       <td>rgb(135,206,250)</td>
#    </tr>
#    <tr>
#       <td>29</td>
#       <td style="background:skyblue;">&nbsp;</td>
#       <td>skyblue</td>
#       <td>#87CEEB</td>
#       <td>rgb(135,206,235)</td>
#    </tr>
#    <tr>
#       <td>30</td>
#       <td style="background:deepskyblue;">&nbsp;</td>
#       <td>deepskyblue</td>
#       <td>#00BFFF</td>
#       <td>rgb(0,191,255)</td>
#    </tr>
#    <tr>
#       <td>31</td>
#       <td style="background:lightsteelblue;">&nbsp;</td>
#       <td>lightsteelblue</td>
#       <td>#B0C4DE</td>
#       <td>rgb(176,196,222)</td>
#    </tr>
#    <tr>
#       <td>32</td>
#       <td style="background:dodgerblue;">&nbsp;</td>
#       <td>dodgerblue</td>
#       <td>#1E90FF</td>
#       <td>rgb(30,144,255)</td>
#    </tr>
# </table>
#    </body>
# </html>

# %%
soup = BeautifulSoup(data,"html5lib")

# %%
#find a html table in the web page
table = soup.find('table') # in html table is represented by the tag <table>

# %%
#Get all rows from the table
for row in table.find_all('tr'): # in html table row is represented by the tag <tr>
    # Get all columns in each row.
    cols = row.find_all('td') # in html a column is represented by the tag <td>
    color_name = cols[2].getText() # store the value in column 3 as color_name
    color_code = cols[3].getText() # store the value in column 4 as color_code
    print("{}--->{}".format(color_name,color_code))
# Out:
# Color Name--->Hex Code#RRGGBB
# lightsalmon--->#FFA07A
# salmon--->#FA8072
# darksalmon--->#E9967A
# lightcoral--->#F08080
# coral--->#FF7F50
# tomato--->#FF6347
# orangered--->#FF4500
# gold--->#FFD700
# orange--->#FFA500
# darkorange--->#FF8C00
# lightyellow--->#FFFFE0
# lemonchiffon--->#FFFACD
# papayawhip--->#FFEFD5
# moccasin--->#FFE4B5
# peachpuff--->#FFDAB9
# palegoldenrod--->#EEE8AA
# khaki--->#F0E68C
# darkkhaki--->#BDB76B
# yellow--->#FFFF00
# lawngreen--->#7CFC00
# chartreuse--->#7FFF00
# limegreen--->#32CD32
# lime--->#00FF00
# forestgreen--->#228B22
# green--->#008000
# powderblue--->#B0E0E6
# lightblue--->#ADD8E6
# lightskyblue--->#87CEFA
# skyblue--->#87CEEB
# deepskyblue--->#00BFFF
# lightsteelblue--->#B0C4DE
# dodgerblue--->#1E90FF

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01).
